# %%
import pandas as pd
df = pd.read_csv("region.csv")
for index, row in df.iterrows():
    print(row["REGION_ID"], row["REGION_NAME"])
# Out:
# 1  Europe
# 2  Americas
# 3  Asia
# 4  Middle East and Africa
