# %%
import json

data = {
    "name": "Tran Van C",
    "age": 26,
    "score": 8.5,
    "passed": True
}

json_data = json.dumps(
    data,
    sort_keys=True,
    indent=4,
    ensure_ascii=False
)

print(json_data)
# Out:
# {
#     "age": 26,
#     "name": "Tran Van C",
#     "passed": true,
#     "score": 8.5
# }
