# %%
import tkinter as tk
window = tk.Tk()
label = tk.Label(window, text="Hello DHKL18A3HN!")
label.pack()
window.title("Wellcome to UNETI")
window.geometry('280x60')
window.mainloop()

# %%
import tkinter as tk
window = tk.Tk()
label = tk.Label(window, text="Hello 2026", font = ("Arial Bold", 50))
label.pack()
window.title("Hello DHKL18a3HN")
window.geometry('380x80')
label.grid(column=0, row=0)
window.mainloop()

# %%
import tkinter as tk

window = tk.Tk()
window.title("Welcome to UNETI")
window.geometry('450x120')

lbl = tk.Label(window, text="Hello")
lbl.grid(column=0, row=0)

def click():
    lbl.configure(text="Button was clicked")

btn = tk.Button(window, text="Click me", bg="orange", fg="red", command=click)
btn.grid(column=1, row=0)

window.mainloop()

# %%
import tkinter as tk
class UnetiApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Wellcome to Uneti app")
        self.root.grometr('350x80')
        self.lbl1 = tk.Label(root, text = "Giang Vien")
        self.lbl.grid(collum = 0, row = 0)
        self.txt1 = tk.Entry(root, width= 25)
        self.txt1.focus()

        self.lbl2 = tk.Label(root, text = "Bo Mon")
        self.lbl2.grid(collum = 0, row = 2)

        self.txt2 = tk.Entry(root, width= 15)
        self.txt2.grid(collum = 1, row = 2)
        self.txt2.focus()

        self.lbl3 = tk.Label(root, text = "HP Giang day")
        self.lbl3.grid(collum = 0, row = 3)
        self.txt3 = tk.Entry(root, width= 15)
        self.txt3.grid(collum = 1, row = 3)
        self.txt3.focus()
if __name__ == "main":
    root = tk.Tk()
    app = UnetiApp(root)
    root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
class ComboboxApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Wellcome to Uneti App")
        self.root.geometry('350x80')
        self.options=["DHDS16A1", "DHDS 16A2", "DHDS17A1", "DHDS 17A2", "DHDS 17A3"]
        self.teacher_label = tk.Label(root, text="Giảng viên:")
        self.teacher_label.grid(row=0, column=0, padx=5, pady=5)
        self.teacher_textbox = tk.Text(root, height=1, width=20)
        self.teacher_textbox.grid(row=0, column=1, padx=5, pady=5)
        self.label = tk.Label(root, text="Lớp giảng dạy:")
        self.label.grid(row=1, column=0, padx=5, pady=5)
        self.combobox = ttk.Combobox(root, values=self.options)
        self.combobox.grid(row=1, column=1, padx=5, pady=5)
        self.combobox.bind("<<ComboboxSelected>>", self.on_select)
    def on_select(self, event):
        selected_value = self.combobox.get()
        print("Selected:", selected_value)
root = tk.Tk()
app = ComboboxApp(root)
root.mainloop()

# %%
class CheckBoxApp:
    def _0_init__(self, root):
        self.root = root
        self.root.title("Wellcome to Uneti App")
        self.root.geometry('450x120')
        self.var = tk.BooleanVar()
        self.checkbox = tk.Checkbutton(root, text = "Hay Click vao toi", variable=self.var, command=self.on_check_click)
        self.checkbox.pack()
    def on_check_click(self):
        if self.var.get():
            print("Checkbox is Checked")
        else: 
            print("Checkbox is inchecked")
if __name__ == "main":
    root = tk.Tk()
    app = CheckBoxApp(root)
    root.mainloop()

# %%
class RadioButton:
    def __init__(self, root):
        self.root = root
        self.root.title("Raido Button Example")
        self.root.geometry('300x80')
        self.selected_option = tk.IntVar()
        self.radio1 = tk.Radiobutton(self.root, text = "Cau tra loi so 1", variable= self.on_radio_select, value= 1)
        self.radio2 = tk.Radiobutton(self.root, text = "Cau tra loi so 2", variable= self.on_radio_select, value= 2)
        self.radio3 = tk.Radiobutton(self.root, text = "Cau tra loi so 3", variable= self.on_radio_select, value= 3)
        self.radio1.pack()
        self.radio2.pack()
        self.radio3.pack()
    def on_radio_select(self):
        selected_value = self.selected_option.get()
        print("")

# %%
class ListBox:
    def __init__(self, root):
        self.root = root
        self.root.title(root, text = "ListBox Example")
        self.root.gometry('300x250')
        self.create_widgets()
    def create_widgets(self):
        self.lbl = tk.Label(root, text = "Danh sach hoc phan")
        self.lbl.pack()
        hoc_phan = ['DSTT', 'Giai Tich', 'Lap Trinh R']
        self.listbox = tk.Listbox(self.root, selectmode = tk.MULTIPLE)
        self.listbox.pack()
        for i in hoc_phan:
            self.listbox.insert(tk.END, f"{i}")
        self.select_buttom = tk.Button(self.root, text = "Lua chon hoc phan", command = self.on_select)
        self.select_buttom.pack(pady = 10)
    def on_select(self):
        select_items = [self.listbox.get(index) for index in self.listbox.curselection()]
        print("Sel", select_items)
if __name__ == "main":
    root = tk.Tk()
    app = ListBox(root)
    root.mainloop()

# %%
def on_scale_change(value):
    label.config(text = f"Gia tri: {value}")
root = tk.Tk()
root.title("Scale Example")
root.geometry('300x100')
scale = tk.Scale(root, from_ = 0, to =100, resolution= 1, orient= tk.HORIZONTAL, length=200, command= on_scale_change)
scale.set(50)
scale.pack()
label = ttk.Label(root, text = "Gia tri 50")
label.pack()
root.mainloop()

# %%
from tkinter import messagebox
window = tk.Tk()
window.title("Wellcome KHUD app")
window.geometry('350x200')
def clicked():
    messagebox.showinfo("Bm toan ud", "Day la messagebox")
    messagebox.askokcancel("Bm toan ud ", "anh chi co muon lam khoa luan khong")
    messagebox.showwarning("BM toan ud", "Ban can hoc tap tot de thi tot")
btn = tk.Button(window, text= "Bam vao day", command= clicked)
btn.grid(column= 0, row= 0)
window.mainloop()

# %%
import tkinter as tk
class CheckboxApp:
    def __init__(self, root):
        self.root = root
        self.root.title("Checkbox Example")
        self.root.geometry('300x50')
        self.var = tk.BooleanVar()
        self.checkbox = tk.Checkbutton(root, text="Check me",
        variable=self.var,
        command=self.on_checkbox_click)
        self.checkbox.pack()
    def on_checkbox_click(self):
        if self.var.get():
            print("Checkbox is checked.")
        else:
            print("Checkbox is unchecked.")
if __name__ == "__main__":
    root = tk.Tk()
    app = CheckboxApp(root)
    root.mainloop()

# %%
import tkinter as tk

class RadioButtonExample:
    def __init__(self, root):
        self.root = root
        self.root.title("Radio Button Example")
        self.root.geometry('300x120')

        self.selected_option = tk.IntVar()

        self.radio1 = tk.Radiobutton(
            self.root, text="Option 1",
            variable=self.selected_option, value=1,
            command=self.on_radio_select
        )
        self.radio2 = tk.Radiobutton(
            self.root, text="Option 2",
            variable=self.selected_option, value=2,
            command=self.on_radio_select
        )
        self.radio3 = tk.Radiobutton(
            self.root, text="Option 3",
            variable=self.selected_option, value=3,
            command=self.on_radio_select
        )

        self.radio1.pack()
        self.radio2.pack()
        self.radio3.pack()

    def on_radio_select(self):
        selected_value = self.selected_option.get()
        print(f"Option {selected_value} is selected.")

if __name__ == "__main__":
    root = tk.Tk()
    app = RadioButtonExample(root)
    root.mainloop()

# %%
from tkinter import Tk, W, E
from tkinter.ttk import Frame, Button, Style, Entry


class Calculator(Frame):

    def __init__(self, parent):
        super().__init__(parent)
        self.parent = parent
        self.initGUI()

    def initGUI(self):
        self.parent.title("Ứng dụng tính toán")

        Style().configure("TButton", padding=(0, 5, 0, 5),
                          font='serif 10')

        for i in range(4):
            self.columnconfigure(i, pad=3)
        for i in range(6):
            self.rowconfigure(i, pad=3)

        entry = Entry(self)
        entry.grid(row=0, columnspan=4, sticky=W+E)

        Button(self, text="Xóa").grid(row=1, column=0)
        Button(self, text="Quay lại").grid(row=1, column=1)
        Button(self).grid(row=1, column=2)
        Button(self, text="Kết thúc").grid(row=1, column=3)

        Button(self, text="1").grid(row=2, column=0)
        Button(self, text="2").grid(row=2, column=1)
        Button(self, text="3").grid(row=2, column=2)
        Button(self, text="/").grid(row=2, column=3)

        Button(self, text="4").grid(row=3, column=0)
        Button(self, text="5").grid(row=3, column=1)
        Button(self, text="6").grid(row=3, column=2)
        Button(self, text="*").grid(row=3, column=3)

        Button(self, text="7").grid(row=4, column=0)
        Button(self, text="8").grid(row=4, column=1)
        Button(self, text="9").grid(row=4, column=2)
        Button(self, text="-").grid(row=4, column=3)

        Button(self, text="0").grid(row=5, column=0)
        Button(self, text=".").grid(row=5, column=1)
        Button(self, text="=").grid(row=5, column=2)
        Button(self, text="+").grid(row=5, column=3)

        self.pack()


if __name__ == "__main__":
    window_root = Tk()
    app = Calculator(window_root)
    window_root.mainloop()

# %%
import tkinter as tk

class TextEditorApp:
    def __init__(self, win):
        self.win = win  # Cửa sổ chính
        self.win.title("ScrollText Example")
        self.win.geometry('280x120')

        # Đặt màu nền cửa sổ
        self.win.configure(background="#CCFFFF")

        # Tạo Frame chứa Text và Scrollbar
        self.frame1 = tk.Frame(
            self.win, width=100, height=40,
            bg='#BB0000', borderwidth=1, relief='sunken'
        )

        # Tạo Scrollbar
        self.scrollbar = tk.Scrollbar(self.frame1)

        # Tạo Text widget
        self.editArea = tk.Text(
            self.frame1, width=30, height=3,
            wrap="word",
            yscrollcommand=self.scrollbar.set,
            borderwidth=0,
            highlightthickness=0
        )

        # Liên kết Scrollbar với Text
        self.scrollbar.config(command=self.editArea.yview)

        # Sắp xếp widget
        self.scrollbar.pack(side="right", fill="y")
        self.editArea.pack(side="left", fill="both", expand=True)

        # Đặt frame vào cửa sổ chính
        self.frame1.place(x=10, y=30)

    def run(self):
        # Vòng lặp chính của ứng dụng
        self.win.mainloop()

if __name__ == "__main__":
    win = tk.Tk()
    app = TextEditorApp(win)
    app.run()

# %%
import tkinter as tk

class ListBoxExample:
    def __init__(self, root):
        self.root = root
        self.root.title("ListBox Example")
        self.root.geometry('300x250')
        self.create_widgets()

    def create_widgets(self):
        self.lbl = tk.Label(self.root, text="Học phần:")
        self.lbl.pack()

        hoc_phan = [
            'ĐSTT', 'Giải tích', 'Xác suất TK', 'Lập trình R',
            'Lập trình Python', 'Toán RR', 'Cơ sở DL',
            'Cấu trúc DL & GT', 'Thống kê', 'SQL'
        ]

        self.listbox = tk.Listbox(self.root, selectmode=tk.MULTIPLE)
        self.listbox.pack()

        for i in hoc_phan:
            self.listbox.insert(tk.END, i)

        self.select_button = tk.Button(
            self.root, text="Select",
            command=self.on_select
        )
        self.select_button.pack(pady=10)

    def on_select(self):
        selected_items = [
            self.listbox.get(index)
            for index in self.listbox.curselection()
        ]
        print("Selected Items:", selected_items)

if __name__ == "__main__":
    root = tk.Tk()
    app = ListBoxExample(root)
    root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk

def on_scale_change(value):
    label.config(text=f"Giá trị: {value}")

root = tk.Tk()
root.title("Scale Example")
root.geometry("300x100")

scale = tk.Scale(
    root, from_=0, to=100,
    resolution=1,
    orient=tk.HORIZONTAL,
    length=200,
    command=on_scale_change
)
scale.set(50)  # Giá trị mặc định
scale.pack()

label = ttk.Label(root, text="Giá trị: 50")
label.pack()

root.mainloop()

# %%
import tkinter as tk

def on_spinbox_changed():
    value = spinbox.get()
    label2.config(text="Giá trị đã chọn: " + value)

root = tk.Tk()
root.title("SpinBox Example")
root.geometry('300x80')

spinbox = tk.Spinbox(root, from_=1, to=10, increment=1, width=10)
spinbox.grid(row=0, column=2)

label1 = tk.Label(root, text="Chọn giá trị:", anchor="e")
label1.grid(row=0, column=0, padx=5, pady=5)

label2 = tk.Label(
    root,
    text="Giá trị đã chọn là:",
    width=20,
    anchor="e"
)
label2.grid(row=1, column=0, padx=5, pady=5, columnspan=2)

button = tk.Button(
    root,
    text="Kết quả",
    width=10,
    command=on_spinbox_changed
)
button.grid(row=1, column=0, padx=5, pady=5, sticky="w")

root.mainloop()

# %%
import tkinter as tk
from tkinter import filedialog

def open_file():
    file_path = filedialog.askopenfilename()
    if file_path:
        print("Selected file:", file_path)

def open_folder():
    folder_path = filedialog.askdirectory()
    if folder_path:
        print("Selected folder:", folder_path)

root = tk.Tk()
root.title('Demo mở file, thư mục')
root.geometry('300x80')

btn_open_file = tk.Button(
    root, text="Open File",
    command=open_file
)
btn_open_file.pack(padx=5, pady=5)

btn_open_folder = tk.Button(
    root, text="Open Folder",
    command=open_folder
)
btn_open_folder.pack(padx=5, pady=5)

root.mainloop()

# %%
import tkinter as tk

def select1():
    print("Bạn đã chọn menu con 'New'!")

def select2():
    print("Bạn đã chọn menu con 'Open'!")

def select3():
    print("Bạn đã chọn menu con 'Cut'!")

def select4():
    print("Bạn đã chọn menu con 'Copy'!")

def select5():
    print("Bạn đã chọn menu con 'Paste'!")

def quit_app():
    root.quit()

root = tk.Tk()
root.title("Menu Example")
root.geometry('300x80')

menu_bar = tk.Menu(root)
root.config(menu=menu_bar)

# Menu File
file_menu = tk.Menu(menu_bar, tearoff=0)
menu_bar.add_cascade(label="File", menu=file_menu)
file_menu.add_command(label="New", command=select1)
file_menu.add_command(label="Open", command=select2)
file_menu.add_separator()
file_menu.add_command(label="Exit", command=quit_app)

# Menu Edit
edit_menu = tk.Menu(menu_bar, tearoff=0)
menu_bar.add_cascade(label="Edit", menu=edit_menu)
edit_menu.add_command(label="Cut", command=select3)
edit_menu.add_command(label="Copy", command=select4)
edit_menu.add_command(label="Paste", command=select5)

root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
root = tk.Tk()
root.title("Tabs Example")
root.geometry('300x80')
notebook = ttk.Notebook(root)
tab1 = ttk.Frame(notebook)
tab2 = ttk.Frame(notebook)
notebook.add(tab1, text="Tab 1")
notebook.add(tab2, text="Tab 2")
label1 = tk.Label(tab1, text="This is Tab 1")
label1.pack(padx=5,pady=5)
label2 = tk.Label(tab2, text="This is Tab 2")
label2.pack(padx=5,pady=5)
notebook.pack(fill="both", expand=True)
root.mainloop()

# %%
import tkinter as tk
from tkinter import ttk
root = tk.Tk()
root.title("Tabs Example")
root.geometry('300x80')
notebook = ttk.Notebook(root)
tab1 = ttk.Frame(notebook)
tab2 = ttk.Frame(notebook)
notebook.add(tab1, text="Tab 1")
notebook.add(tab2, text="Tab 2")
label1 = tk.Label(tab1, text="This is Tab 1")
label1.pack(padx=5,pady=5)
label2 = tk.Label(tab2, text="This is Tab 2")
label2.pack(padx=5,pady=5)
notebook.pack(fill="both", expand=True)
root.mainloop()

# %%
from tkinter import *
parent = Tk()
parent.geometry("200x50")
redbutton = Button(parent, text="Red", fg="red")
redbutton.pack(side=LEFT)
greenbutton = Button(parent, text="Black", fg="black")
greenbutton.pack(side=RIGHT)
bluebutton = Button(parent, text="Blue", fg="blue")
bluebutton.pack(side=TOP)
blackbutton = Button(parent, text="Green", fg="green")
blackbutton.pack(side=BOTTOM)
parent.mainloop()

# %%
import tkinter as tk
from tkinter import BOTH, X, N, LEFT
from tkinter.ttk import Frame, Label, Entry

class Demo_2(Frame):
    def __init__(self, parent):
        super().__init__(parent)
        self.parent = parent
        self.initGUI()

    def initGUI(self):
        self.parent.title("Khoa Khoa học ứng dụng")
        self.pack(fill=BOTH, expand=True)

        # Frame 1: Giảng viên
        frame1 = Frame(self)
        frame1.pack(fill=X)

        lbl1 = Label(frame1, text="Giảng viên:", width=10)
        lbl1.pack(side=LEFT, padx=5, pady=5)

        entry1 = Entry(frame1)
        entry1.pack(fill=X, padx=5, expand=True)

        # Frame 2: Bộ môn
        frame2 = Frame(self)
        frame2.pack(fill=X)

        lbl2 = Label(frame2, text="Bộ môn:", width=10)
        lbl2.pack(side=LEFT, padx=5, pady=5)

        entry2 = Entry(frame2)
        entry2.pack(fill=X, padx=5, expand=True)

        # Frame 3: Dự án
        frame3 = Frame(self)
        frame3.pack(fill=BOTH, expand=True)

        lbl3 = Label(frame3, text="Dự án:", width=10)
        lbl3.pack(side=LEFT, anchor=N, padx=5, pady=5)

        txt = tk.Text(frame3)
        txt.pack(fill=BOTH, pady=5, padx=5, expand=True)

if __name__ == "__main__":
    windows_root = tk.Tk()
    windows_root.geometry("320x200+320+200")
    app = Demo_2(windows_root)
    windows_root.mainloop()

# %%
pip install pyQt5
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import sys
from PyQt5.QtWidgets import QApplication, QLabel, QWidget

class HelloWorld(QWidget):
    def __init__(self):
        super().__init__()
        self.init_ui()

    def init_ui(self):
        self.setWindowTitle("Hello World!")
        self.setGeometry(300, 300, 300, 200)

        label = QLabel("Hello World!", self)
        label.move(100, 80)

if __name__ == "__main__":
    app = QApplication(sys.argv)
    window = HelloWorld()
    window.show()
    sys.exit(app.exec_())
