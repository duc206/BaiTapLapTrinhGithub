# %%
import tkinter as tk

def tinh_tong():
    n = int(entry.get())
    tong = 0
    for i in range(1, n+1):
        tong += i
    lbl.config(text=f"The sum is 1 + 2 + ... + {n} = {tong}")

root = tk.Tk()
root.title("Sum")

tk.Label(root, text="Enter value of integer N:").pack()
entry = tk.Entry(root)
entry.pack()

tk.Button(root, text="Validate", command=tinh_tong).pack(pady=5)
lbl = tk.Label(root, text="")
lbl.pack()

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_7096\1564066435.py", line 4, in tinh_tong
#     n = int(entry.get())
# ValueError: invalid literal for int() with base 10: '1+1'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "c:\Users\admin\AppData\Local\Programs\Python\Python313\Lib\tkinter\__init__.py", line 2068, in __call__
#     return self.func(*args)
#            ~~~~~~~~~^^^^^^^
#   File "C:\Users\admin\AppData\Local\Temp\ipykernel_7096\1564066435.py", line 4, in tinh_tong
#     n = int(entry.get())
# ValueError: invalid literal for int() with base 10: '1+1'
